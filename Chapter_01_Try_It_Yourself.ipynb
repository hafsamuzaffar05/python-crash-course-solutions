# %%
print("Hello Python world!")

print("hello python world!")

print("I am learning Python step by step!")

print("This is my first real Python file.")

print("Coding is fun and I will become better every day!")

print("My name is Hafsa and I love learning new things!")
# Out:
# Hello Python world!
# hello python world!
# I am learning Python step by step!
# This is my first real Python file.
# Coding is fun and I will become better every day!
# My name is Hafsa and I love learning new things!
