# %%
message = "This is my first message!"
print(message)


message = "I love Python!"
print(message)

message = "I’m going to be great at coding!"
print(message)

name = "Hafsa"
print(f"Hello {name}, would you like to learn some Python today?")

name = "hafsa muzaffar"
print(name.lower())
print(name.upper())
print(name.title())

print('Albert Einstein once said, "A person who never made a mistake never tried anything new."')

famous_person = "Albert Einstein"
message = f'{famous_person} once said, "A person who never made a mistake never tried anything new."'
print(message)


name_with_spaces = "\t\n Hafsa Muzaffar \n\t"
print("Original:", name_with_spaces)
print("lstrip():", name_with_spaces.lstrip())
print("rstrip():", name_with_spaces.rstrip())
print("strip():", name_with_spaces.strip())


filename = "python_notes.txt"
print(filename.removesuffix(".txt"))
# Out:
# This is my first message!
# I love Python!
# I’m going to be great at coding!
# Hello Hafsa, would you like to learn some Python today?
# hafsa muzaffar
# HAFSA MUZAFFAR
# Hafsa Muzaffar
# Albert Einstein once said, "A person who never made a mistake never tried anything new."
# Albert Einstein once said, "A person who never made a mistake never tried anything new."
# Original:
#  Hafsa Muzaffar
#
# lstrip(): Hafsa Muzaffar
#
# rstrip():
#  Hafsa Muzaffar
# strip(): Hafsa Muzaffar
# python_notes
