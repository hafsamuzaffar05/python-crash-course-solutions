# %%
names = ["Areeba", "Fatima", "Zoya"]
print(names[0])
print(names[1])
print(names[2])

print(f"Hello {names[0]}, hope you're doing great!")
print(f"Hello {names[1]}, have a good day!")
print(f"Hello {names[2]}, keep shining!")

vehicles = ["Honda motorcycle", "Tesla car", "Yamaha bike"]
print(f"I would like to own a {vehicles[0]}.")
print(f"I would like to own a {vehicles[1]}.")
print(f"I would like to own a {vehicles[2]}.")

guests = ["Ali", "Sara", "Ahmed"]
print(f"{guests[0]}, you are invited to dinner.")
print(f"{guests[1]}, you are invited to dinner.")
print(f"{guests[2]}, you are invited to dinner.")

print(f"{guests[1]} can't make it to dinner.")
guests[1] = "Fatima"
print(f"{guests[0]}, you are invited to dinner.")
print(f"{guests[1]}, you are invited to dinner.")
print(f"{guests[2]}, you are invited to dinner.")

guests.insert(0, "Zara")
guests.insert(2, "Bilal")
guests.append("Hassan")
print(f"{guests[0]}, you are invited to dinner.")
print(f"{guests[1]}, you are invited to dinner.")
print(f"{guests[2]}, you are invited to dinner.")
print(f"{guests[3]}, you are invited to dinner.")
print(f"{guests[4]}, you are invited to dinner.")
print(f"{guests[5]}, you are invited to dinner.")

print("Sorry, I can invite only two people.")
popped_guest = guests.pop()
print(f"Sorry {popped_guest}, I can’t invite you.")
popped_guest = guests.pop()
print(f"Sorry {popped_guest}, I can’t invite you.")
popped_guest = guests.pop()
print(f"Sorry {popped_guest}, I can’t invite you.")
popped_guest = guests.pop()
print(f"Sorry {popped_guest}, I can’t invite you.")

print(f"{guests[0]}, you’re still invited.")
print(f"{guests[1]}, you’re still invited.")

del guests[0]
del guests[0]

print(guests)

places = ["Japan", "Turkey", "Maldives", "Switzerland", "Italy"]
print(places)
print(sorted(places))
print(places)
print(sorted(places, reverse=True))
print(places)
places.reverse()
print(places)
places.reverse()
print(places)
places.sort()
print(places)
places.sort(reverse=True)
print(places)


guests = ["Ali", "Sara", "Ahmed"]
print(len(guests))

languages = ["Python", "Java", "C++", "Ruby", "JavaScript"]
print(languages)
print(languages[0])
languages.append("Swift")
print(languages)
languages.insert(1, "Go")
print(languages)
del languages[2]
print(languages)
popped_lang = languages.pop()
print(popped_lang)
languages.remove("Go")
print(languages)
languages.sort()
print(languages)
languages.sort(reverse=True)
print(languages)
languages.reverse()
print(languages)
print(len(languages))
# Out:
# Areeba
# Fatima
# Zoya
# Hello Areeba, hope you're doing great!
# Hello Fatima, have a good day!
# Hello Zoya, keep shining!
# I would like to own a Honda motorcycle.
# I would like to own a Tesla car.
# I would like to own a Yamaha bike.
# Ali, you are invited to dinner.
# Sara, you are invited to dinner.
# Ahmed, you are invited to dinner.
# Sara can't make it to dinner.
# Ali, you are invited to dinner.
# Fatima, you are invited to dinner.
# Ahmed, you are invited to dinner.
# Zara, you are invited to dinner.
# Ali, you are invited to dinner.
# Bilal, you are invited to dinner.
# Fatima, you are invited to dinner.
# Ahmed, you are invited to dinner.
# Hassan, you are invited to dinner.
# Sorry, I can invite only two people.
# Sorry Hassan, I can’t invite you.
# Sorry Ahmed, I can’t invite you.
# Sorry Fatima, I can’t invite you.
# Sorry Bilal, I can’t invite you.
# Zara, you’re still invited.
# Ali, you’re still invited.
# []
# ...
